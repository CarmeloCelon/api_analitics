# %%
import pandas as pd

# %%
client = pd.read_csv('client_id.csv', index_col=0)

# %%
client[client['day'] == '2023-01-27']
# Out:
#             day           campaign  source medium channelGrouping  \
# 673  2023-01-27  CPC_S_CMA_Testing  google    cpc     Paid Search
# 674  2023-01-27  CPC_S_CMA_Testing  google    cpc     Paid Search
# 675  2023-01-27  CPC_S_CMA_Testing  google    cpc     Paid Search
# 676  2023-01-27  CPC_S_CMA_Testing  google    cpc     Paid Search
# 677  2023-01-27  CPC_S_CMA_Testing  google    cpc     Paid Search
# 678  2023-01-27  CPC_S_CMA_Testing  google    cpc     Paid Search
# 679  2023-01-27  CPC_S_CMA_Testing  google    cpc     Paid Search
#
#        dimension3                    hostname  \
# 673  1.186032e+09  www.tuclinicavitaldent.com
# 674  2.305299e+08  www.tuclinicavitaldent.com
# 675  3.850789e+08  www.tuclinicavitaldent.com
# 676  4.028046e+08  www.tuclinicavitaldent.com
# 677  4.525633e+07  www.tuclinicavitaldent.com
# 678  4.867262e+08  www.tuclinicavitaldent.com
# 679  9.697835e+08  www.tuclinicavitaldent.com
#
# ...
